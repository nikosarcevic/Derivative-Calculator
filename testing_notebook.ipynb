# %%
from hybrid_derivative_calculator import HybridDerivativeCalculator
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
def run_tests():
    test_cases = [
    {"name": "x^2", "func": lambda x: x**2},
    {"name": "x^3", "func": lambda x: x**3},
    {"name": "sin(x)", "func": lambda x: np.sin(x)},
    {"name": "cos(x)", "func": lambda x: np.cos(x)},
    {"name": "tan(x)", "func": lambda x: np.tan(x)},
    {"name": "exp(x)", "func": lambda x: np.exp(x)},
    {"name": "ln(x + 2)", "func": lambda x: np.log(x + 2)},
    {"name": "sqrt(x + 1)", "func": lambda x: np.sqrt(x + 1)},
    {"name": "1 / (1 + x^2)", "func": lambda x: 1 / (1 + x**2)},
    {"name": "x * sin(x)", "func": lambda x: x * np.sin(x)},
    {"name": "x^2 * cos(x)", "func": lambda x: x**2 * np.cos(x)},
    {"name": "x * exp(-x^2)", "func": lambda x: x * np.exp(-x**2)},
    {"name": "exp(-x^2) * sin(5x)", "func": lambda x: np.exp(-x**2) * np.sin(5 * x)},
    {"name": "log(1 + x^2) * sin(x)", "func": lambda x: np.log(1 + x**2) * np.sin(x)},
    {"name": "sin(x) * cos(x)", "func": lambda x: np.sin(x) * np.cos(x)},
    {"name": "abs(x)", "func": lambda x: np.abs(x)},
    {"name": "Piecewise (x^2 / sqrt(x+1))", "func": lambda x: x**2 if x < 0 else np.sqrt(x + 1)},
    {"name": "Piecewise sin or cos", "func": lambda x: np.sin(x) if x < 1 else np.cos(x)},
    {"name": "ReLU", "func": lambda x: max(0, x)},
    {"name": "x * |x|", "func": lambda x: x * abs(x)},
    {"name": "Heaviside(x)", "func": lambda x: 0 if x < 0 else 1},
    {"name": "sin(x^2)", "func": lambda x: np.sin(x**2)},
    {"name": "exp(sin(x))", "func": lambda x: np.exp(np.sin(x))},
    {"name": "log(cos(x)^2 + 1)", "func": lambda x: np.log(np.cos(x)**2 + 1)},
    {"name": "weird combo", "func": lambda x: x**3 * np.cos(x**2) + np.exp(-x**2)},

    # Extra complicated functions
    {"name": "log(|sin(x)| + 1)", "func": lambda x: np.log(np.abs(np.sin(x)) + 1)},
    {"name": "exp(-x^2) * cos(10x)", "func": lambda x: np.exp(-x**2) * np.cos(10 * x)},
    {"name": "arctan(exp(x))", "func": lambda x: np.arctan(np.exp(x))},
    {"name": "nested trig log", "func": lambda x: np.log(np.abs(np.sin(x)) + 1e-3)},
    {"name": "sqrt(sin^2(x) + cos^2(x))", "func": lambda x: np.sqrt(np.sin(x)**2 + np.cos(x)**2)},
    {"name": "sigmoid", "func": lambda x: 1 / (1 + np.exp(-x))},
    {"name": "softplus", "func": lambda x: np.log(1 + np.exp(x))},
    {"name": "x * tanh(x)", "func": lambda x: x * np.tanh(x)},
    {"name": "gaussian bump", "func": lambda x: np.exp(-1 / (1 - x**2)) if abs(x) < 1 else 0},
    {"name": "x^x (safe)", "func": lambda x: x**x if x > 0 else 0},
    {"name": "sin(exp(x))", "func": lambda x: np.sin(np.exp(x))},
    {"name": "cos(sin(x^2))", "func": lambda x: np.cos(np.sin(x**2))},
    {"name": "sinc(x)", "func": lambda x: np.sinc(x / np.pi)},  # normalized sinc
]

    x_vals = [-16, -5, 0.0, 0.5, 3.6]
    print("\n=== DERIVATIVE TEST RESULTS ===\n")

    for case in test_cases:
        print(f"Function: {case['name']}")
        for x in x_vals:
            try:
                hdc = HybridDerivativeCalculator(case["func"], x, log_suffix="run")
                stem = hdc.stem_method()
                stencil = hdc.five_point_stencil_method()
                abs_diff = abs(stem - stencil)
                rel_diff = abs_diff / (abs(stencil) + 1e-12)

                print(f"  @ x = {x:>5.1f} | Stem: {stem:>10.6f} | Stencil: {stencil:>10.6f} | Δ: {abs_diff:>8.2e} | Rel Δ: {rel_diff:>6.2e}", end="")
                if rel_diff > 0.05:
                    print("  ⚠️")
                else:
                    print("  ✅")
            except Exception as e:
                print(f"  @ x = {x:>5.1f} → ❌ Error: {str(e)}")
        print("-" * 80)

if __name__ == "__main__":
    run_tests()
# Out:
# === DERIVATIVE TEST RESULTS ===
#
# Function: x^2
#   @ x = -16.0 | Stem: -32.000000 | Stencil: -32.000000 | Δ: 1.33e-12 | Rel Δ: 4.15e-14  ✅
#   @ x =  -5.0 | Stem: -10.000000 | Stencil: -10.000000 | Δ: 2.68e-13 | Rel Δ: 2.68e-14  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   1.000000 | Stencil:   1.000000 | Δ: 2.89e-15 | Rel Δ: 2.89e-15  ✅
#   @ x =   3.6 | Stem:   7.200000 | Stencil:   7.200000 | Δ: 4.00e-14 | Rel Δ: 5.55e-15  ✅
# --------------------------------------------------------------------------------
# Function: x^3
#   @ x = -16.0 | Stem: 813.177491 | Stencil: 768.000000 | Δ: 4.52e+01 | Rel Δ: 5.88e-02  ⚠️
#   @ x =  -5.0 | Stem:  79.411864 | Stencil:  75.000000 | Δ: 4.41e+00 | Rel Δ: 5.88e-02  ⚠️
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   0.794651 | Stencil:   0.750000 | Δ: 4.47e-02 | Rel Δ: 5.95e-02  ⚠️
#   @ x =   3.6 | Stem:  41.167110 | Stencil:  38.880000 | Δ: 2.29e+00 | Rel Δ: 5.88e-02  ⚠️
# --------------------------------------------------------------------------------
# Function: sin(x)
#   @ x = -16.0 | Stem:  -0.957659 | Stencil:  -0.957659 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.283662 | Stencil:   0.283662 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.998798 | Stencil:   1.000000 | Δ: 1.20e-03 | Rel Δ: 1.20e-03  ✅
#   @ x =   0.5 | Stem:   0.877319 | Stencil:   0.877583 | Δ: 2.64e-04 | Rel Δ: 3.01e-04  ✅
#   @ x =   3.6 | Stem:  -0.896758 | Stencil:  -0.896758 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: cos(x)
#   @ x = -16.0 | Stem:  -0.287903 | Stencil:  -0.287903 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:  -0.958924 | Stencil:  -0.958924 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 3.55e-15 | Rel Δ: 3.54e-03  ✅
#   @ x =   0.5 | Stem:  -0.479281 | Stencil:  -0.479426 | Δ: 1.44e-04 | Rel Δ: 3.01e-04  ✅
#   @ x =   3.6 | Stem:   0.442520 | Stencil:   0.442520 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: tan(x)
#   @ x = -16.0 | Stem:   1.090380 | Stencil:   1.090380 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:  12.427811 | Stencil:  12.427811 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   1.002414 | Stencil:   1.000000 | Δ: 2.41e-03 | Rel Δ: 2.41e-03  ✅
#   @ x =   0.5 | Stem:   1.299929 | Stencil:   1.298446 | Δ: 1.48e-03 | Rel Δ: 1.14e-03  ✅
#   @ x =   3.6 | Stem:   1.243509 | Stencil:   1.243509 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: exp(x)
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.006738 | Stencil:   0.006738 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   1.001203 | Stencil:   1.000000 | Δ: 1.20e-03 | Rel Δ: 1.20e-03  ✅
#   @ x =   0.5 | Stem:   1.649217 | Stencil:   1.648721 | Δ: 4.96e-04 | Rel Δ: 3.01e-04  ✅
#   @ x =   3.6 | Stem:  36.598234 | Stencil:  36.598234 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: ln(x + 2)
#   @ x = -16.0 | Stem:        nan | Stencil:        nan | Δ:      nan | Rel Δ:    nan  ✅
#   @ x =  -5.0 | Stem:        nan | Stencil:        nan | Δ:      nan | Rel Δ:    nan  ✅
#   @ x =   0.0 | Stem:   0.500301 | Stencil:   0.500000 | Δ: 3.01e-04 | Rel Δ: 6.02e-04  ✅
#   @ x =   0.5 | Stem:   0.400038 | Stencil:   0.400000 | Δ: 3.85e-05 | Rel Δ: 9.62e-05  ✅
#   @ x =   3.6 | Stem:   0.178749 | Stencil:   0.178571 | Δ: 1.78e-04 | Rel Δ: 9.96e-04  ✅
# --------------------------------------------------------------------------------
# Function: sqrt(x + 1)
#   @ x = -16.0 | Stem:        nan | Stencil:        nan | Δ:      nan | Rel Δ:    nan  ✅
#   @ x =  -5.0 | Stem:        nan | Stencil:        nan | Δ:      nan | Rel Δ:    nan  ✅
#   @ x =   0.0 | Stem:   0.500453 | Stencil:   0.500000 | Δ: 4.53e-04 | Rel Δ: 9.05e-04  ✅
#   @ x =   0.5 | Stem:   0.408289 | Stencil:   0.408248 | Δ: 4.09e-05 | Rel Δ: 1.00e-04  ✅
#   @ x =   3.6 | Stem:   0.233255 | Stencil:   0.233126 | Δ: 1.29e-04 | Rel Δ: 5.54e-04  ✅
# --------------------------------------------------------------------------------
# Function: 1 / (1 + x^2)
#   @ x = -16.0 | Stem:   0.000441 | Stencil:   0.000484 | Δ: 4.37e-05 | Rel Δ: 9.02e-02  ⚠️
#   @ x =  -5.0 | Stem:   0.013511 | Stencil:   0.014793 | Δ: 1.28e-03 | Rel Δ: 8.66e-02  ⚠️
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 1.78e-15 | Rel Δ: 1.77e-03  ✅
#   @ x =   0.5 | Stem:  -0.638893 | Stencil:  -0.640000 | Δ: 1.11e-03 | Rel Δ: 1.73e-03  ✅
#   @ x =   3.6 | Stem:  -0.034394 | Stencil:  -0.036946 | Δ: 2.55e-03 | Rel Δ: 6.91e-02  ⚠️
# --------------------------------------------------------------------------------
# Function: x * sin(x)
#   @ x = -16.0 | Stem:  15.610455 | Stencil:  15.610455 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:  -0.459387 | Stencil:  -0.459387 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   0.917653 | Stencil:   0.918217 | Δ: 5.64e-04 | Rel Δ: 6.14e-04  ✅
#   @ x =   3.6 | Stem:  -3.629407 | Stencil:  -3.670851 | Δ: 4.14e-02 | Rel Δ: 1.13e-02  ✅
# --------------------------------------------------------------------------------
# Function: x^2 * cos(x)
#   @ x = -16.0 | Stem: -43.058146 | Stencil: -43.058146 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem: -26.809729 | Stencil: -26.809729 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   0.756107 | Stencil:   0.757726 | Δ: 1.62e-03 | Rel Δ: 2.14e-03  ✅
#   @ x =   3.6 | Stem:  -0.721596 | Stencil:  -0.721596 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: x * exp(-x^2)
#   @ x = -16.0 | Stem:  -0.000000 | Stencil:  -0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:  -0.000000 | Stencil:  -0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.992820 | Stencil:   1.000000 | Δ: 7.18e-03 | Rel Δ: 7.18e-03  ✅
#   @ x =   0.5 | Stem:   0.389283 | Stencil:   0.389400 | Δ: 1.17e-04 | Rel Δ: 3.02e-04  ✅
#   @ x =   3.6 | Stem:  -0.000059 | Stencil:  -0.000059 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: exp(-x^2) * sin(5x)
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   4.999998 | Stencil:   4.999998 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:  -3.620390 | Stencil:  -3.585745 | Δ: 3.46e-02 | Rel Δ: 9.66e-03  ✅
#   @ x =   3.6 | Stem:   0.000020 | Stencil:   0.000020 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: log(1 + x^2) * sin(x)
#   @ x = -16.0 | Stem:  -5.349973 | Stencil:  -5.349973 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.555382 | Stencil:   0.555382 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   0.598637 | Stencil:   0.579367 | Δ: 1.93e-02 | Rel Δ: 3.33e-02  ✅
#   @ x =   3.6 | Stem:  -2.507234 | Stencil:  -2.592265 | Δ: 8.50e-02 | Rel Δ: 3.28e-02  ✅
# --------------------------------------------------------------------------------
# Function: sin(x) * cos(x)
#   @ x = -16.0 | Stem:   0.834223 | Stencil:   0.834223 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:  -0.839072 | Stencil:  -0.839072 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.995200 | Stencil:   1.000000 | Δ: 4.80e-03 | Rel Δ: 4.80e-03  ✅
#   @ x =   0.5 | Stem:   0.539653 | Stencil:   0.540302 | Δ: 6.49e-04 | Rel Δ: 1.20e-03  ✅
#   @ x =   3.6 | Stem:   0.608351 | Stencil:   0.608351 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: abs(x)
#   @ x = -16.0 | Stem:  -1.000000 | Stencil:  -1.000000 | Δ: 1.69e-13 | Rel Δ: 1.69e-13  ✅
#   @ x =  -5.0 | Stem:  -1.000000 | Stencil:  -1.000000 | Δ: 7.33e-15 | Rel Δ: 7.33e-15  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   1.000000 | Stencil:   1.000000 | Δ: 6.66e-15 | Rel Δ: 6.66e-15  ✅
#   @ x =   3.6 | Stem:   1.000000 | Stencil:   1.000000 | Δ: 1.38e-14 | Rel Δ: 1.38e-14  ✅
# --------------------------------------------------------------------------------
# Function: Piecewise (x^2 / sqrt(x+1))
#   @ x = -16.0 | Stem: -32.000000 | Stencil: -32.000000 | Δ: 1.33e-12 | Rel Δ: 4.15e-14  ✅
#   @ x =  -5.0 | Stem: -10.000000 | Stencil: -10.000000 | Δ: 2.68e-13 | Rel Δ: 2.68e-14  ✅
#   @ x =   0.0 | Stem:  58.579583 | Stencil:  58.579583 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   0.408289 | Stencil:   0.408248 | Δ: 4.09e-05 | Rel Δ: 1.00e-04  ✅
#   @ x =   3.6 | Stem:   0.233255 | Stencil:   0.233126 | Δ: 1.29e-04 | Rel Δ: 5.54e-04  ✅
# --------------------------------------------------------------------------------
# Function: Piecewise sin or cos
#   @ x = -16.0 | Stem:  -0.957659 | Stencil:  -0.957659 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.283662 | Stencil:   0.283662 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.998798 | Stencil:   1.000000 | Δ: 1.20e-03 | Rel Δ: 1.20e-03  ✅
#   @ x =   0.5 | Stem:   0.877319 | Stencil:   0.877583 | Δ: 2.64e-04 | Rel Δ: 3.01e-04  ✅
#   @ x =   3.6 | Stem:   0.442520 | Stencil:   0.442520 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: ReLU
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.500000 | Stencil:   0.500000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   1.000000 | Stencil:   1.000000 | Δ: 6.66e-15 | Rel Δ: 6.66e-15  ✅
#   @ x =   3.6 | Stem:   1.000000 | Stencil:   1.000000 | Δ: 1.38e-14 | Rel Δ: 1.38e-14  ✅
# --------------------------------------------------------------------------------
# Function: x * |x|
#   @ x = -16.0 | Stem:  32.000000 | Stencil:  32.000000 | Δ: 1.33e-12 | Rel Δ: 4.15e-14  ✅
#   @ x =  -5.0 | Stem:  10.000000 | Stencil:  10.000000 | Δ: 2.68e-13 | Rel Δ: 2.68e-14  ✅
#   @ x =   0.0 | Stem:   0.006667 | Stencil:   0.006667 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   1.000000 | Stencil:   1.000000 | Δ: 2.89e-15 | Rel Δ: 2.89e-15  ✅
#   @ x =   3.6 | Stem:   7.200000 | Stencil:   7.200000 | Δ: 4.00e-14 | Rel Δ: 5.55e-15  ✅
# --------------------------------------------------------------------------------
# Function: Heaviside(x)
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:  58.333333 | Stencil:  58.333333 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:  -0.000000 | Stencil:   0.000000 | Δ: 2.37e-15 | Rel Δ: 2.37e-03  ✅
#   @ x =   3.6 | Stem:  -0.000000 | Stencil:   0.000000 | Δ: 1.82e-15 | Rel Δ: 1.82e-03  ✅
# --------------------------------------------------------------------------------
# Function: sin(x^2)
#   @ x = -16.0 | Stem:   1.272652 | Stencil:   1.272652 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:  -9.911996 | Stencil:  -9.911996 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   0.968173 | Stencil:   0.968912 | Δ: 7.39e-04 | Rel Δ: 7.63e-04  ✅
#   @ x =   3.6 | Stem:   6.649360 | Stencil:   6.649360 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: exp(sin(x))
#   @ x = -16.0 | Stem:  -1.277162 | Stencil:  -1.277162 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.740043 | Stencil:   0.740043 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.999996 | Stencil:   1.000000 | Δ: 4.50e-06 | Rel Δ: 4.50e-06  ✅
#   @ x =   0.5 | Stem:   1.416714 | Stencil:   1.417424 | Δ: 7.11e-04 | Rel Δ: 5.01e-04  ✅
#   @ x =   3.6 | Stem:  -0.576091 | Stencil:  -0.576091 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: log(cos(x)^2 + 1)
#   @ x = -16.0 | Stem:   0.287634 | Stencil:   0.287634 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:  -0.503507 | Stencil:  -0.503507 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 2.66e-15 | Rel Δ: 2.66e-03  ✅
#   @ x =   0.5 | Stem:  -0.475121 | Stencil:  -0.475367 | Δ: 2.46e-04 | Rel Δ: 5.17e-04  ✅
#   @ x =   3.6 | Stem:  -0.439906 | Stencil:  -0.439906 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: weird combo
#   @ x = -16.0 | Stem: 130892.529028 | Stencil: 130892.529028 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem: 239.777332 | Stencil: 239.777332 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.007213 | Stencil:   0.000000 | Δ: 7.21e-03 | Rel Δ: 6.55e+08  ⚠️
#   @ x =   0.5 | Stem:  -0.082003 | Stencil:  -0.083042 | Δ: 1.04e-03 | Rel Δ: 1.25e-02  ✅
#   @ x =   3.6 | Stem: -92.934524 | Stencil: -92.934524 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: log(|sin(x)| + 1)
#   @ x = -16.0 | Stem:  -0.743580 | Stencil:  -0.743580 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.144805 | Stencil:   0.144805 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   0.593312 | Stencil:   0.593191 | Δ: 1.21e-04 | Rel Δ: 2.03e-04  ✅
#   @ x =   3.6 | Stem:   0.621661 | Stencil:   0.621661 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: exp(-x^2) * cos(10x)
#   @ x = -16.0 | Stem:  -0.000000 | Stencil:  -0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   7.247170 | Stencil:   7.247170 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   3.6 | Stem:   0.000026 | Stencil:   0.000026 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: arctan(exp(x))
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.006738 | Stencil:   0.006738 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.499400 | Stencil:   0.500000 | Δ: 6.00e-04 | Rel Δ: 1.20e-03  ✅
#   @ x =   0.5 | Stem:   0.443333 | Stencil:   0.443409 | Δ: 7.64e-05 | Rel Δ: 1.72e-04  ✅
#   @ x =   3.6 | Stem:   0.027729 | Stencil:   0.027303 | Δ: 4.25e-04 | Rel Δ: 1.56e-02  ✅
# --------------------------------------------------------------------------------
# Function: nested trig log
#   @ x = -16.0 | Stem:  -3.314806 | Stencil:  -3.314806 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.295505 | Stencil:   0.295505 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:  -0.000000 | Stencil:  -0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   1.831463 | Stencil:   1.826677 | Δ: 4.79e-03 | Rel Δ: 2.62e-03  ✅
#   @ x =   3.6 | Stem:   2.021910 | Stencil:   2.021910 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: sqrt(sin^2(x) + cos^2(x))
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 1.73e-15 | Rel Δ: 1.73e-03  ✅
#   @ x =  -5.0 | Stem:   0.000000 | Stencil:  -0.000000 | Δ: 5.34e-15 | Rel Δ: 5.31e-03  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 1.78e-15 | Rel Δ: 1.77e-03  ✅
#   @ x =   0.5 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 8.81e-15 | Rel Δ: 8.73e-03  ✅
#   @ x =   3.6 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 3.49e-15 | Rel Δ: 3.48e-03  ✅
# --------------------------------------------------------------------------------
# Function: sigmoid
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.006648 | Stencil:   0.006648 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.249850 | Stencil:   0.250000 | Δ: 1.50e-04 | Rel Δ: 6.01e-04  ✅
#   @ x =   0.5 | Stem:   0.234975 | Stencil:   0.235004 | Δ: 2.90e-05 | Rel Δ: 1.23e-04  ✅
#   @ x =   3.6 | Stem:   0.026231 | Stencil:   0.025890 | Δ: 3.41e-04 | Rel Δ: 1.32e-02  ✅
# --------------------------------------------------------------------------------
# Function: softplus
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.006693 | Stencil:   0.006693 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.500000 | Stencil:   0.500000 | Δ: 1.67e-15 | Rel Δ: 3.33e-15  ✅
#   @ x =   0.5 | Stem:   0.622442 | Stencil:   0.622459 | Δ: 1.73e-05 | Rel Δ: 2.78e-05  ✅
#   @ x =   3.6 | Stem:   0.973019 | Stencil:   0.973403 | Δ: 3.84e-04 | Rel Δ: 3.94e-04  ✅
# --------------------------------------------------------------------------------
# Function: x * tanh(x)
#   @ x = -16.0 | Stem:  -1.000000 | Stencil:  -1.000000 | Δ: 1.46e-12 | Rel Δ: 1.46e-12  ✅
#   @ x =  -5.0 | Stem:  -1.000896 | Stencil:  -1.000817 | Δ: 7.90e-05 | Rel Δ: 7.89e-05  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   0.854601 | Stencil:   0.855341 | Δ: 7.40e-04 | Rel Δ: 8.65e-04  ✅
#   @ x =   3.6 | Stem:   1.009635 | Stencil:   1.009243 | Δ: 3.92e-04 | Rel Δ: 3.89e-04  ✅
# --------------------------------------------------------------------------------
# Function: gaussian bump
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:  -0.000000 | Δ: 8.88e-16 | Rel Δ: 8.87e-04  ✅
#   @ x =   0.5 | Stem:  -0.469307 | Stencil:  -0.468617 | Δ: 6.89e-04 | Rel Δ: 1.47e-03  ✅
#   @ x =   3.6 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: x^x (safe)
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:  55.959989 | Stencil:  55.959989 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:   0.216522 | Stencil:   0.216978 | Δ: 4.56e-04 | Rel Δ: 2.10e-03  ✅
#   @ x =   3.6 | Stem: 229.510039 | Stencil: 229.510039 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: sin(exp(x))
#   @ x = -16.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:   0.006738 | Stencil:   0.006738 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.537258 | Stencil:   0.540302 | Δ: 3.04e-03 | Rel Δ: 5.63e-03  ✅
#   @ x =   0.5 | Stem:  -0.130722 | Stencil:  -0.128347 | Δ: 2.38e-03 | Rel Δ: 1.85e-02  ✅
#   @ x =   3.6 | Stem:  16.567760 | Stencil:  16.567760 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: cos(sin(x^2))
#   @ x = -16.0 | Stem:   1.070979 | Stencil:   1.070979 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:  -1.307861 | Stencil:  -1.307861 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 1.78e-15 | Rel Δ: 1.77e-03  ✅
#   @ x =   0.5 | Stem:  -0.238454 | Stencil:  -0.237275 | Δ: 1.18e-03 | Rel Δ: 4.97e-03  ✅
#   @ x =   3.6 | Stem:  -2.488186 | Stencil:  -2.488186 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# Function: sinc(x)
#   @ x = -16.0 | Stem:   0.058729 | Stencil:   0.058729 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =  -5.0 | Stem:  -0.095089 | Stencil:  -0.095089 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.0 | Stem:   0.000000 | Stencil:   0.000000 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
#   @ x =   0.5 | Stem:  -0.162508 | Stencil:  -0.162537 | Δ: 2.92e-05 | Rel Δ: 1.79e-04  ✅
#   @ x =   3.6 | Stem:  -0.214954 | Stencil:  -0.214954 | Δ: 0.00e+00 | Rel Δ: 0.00e+00  ✅
# --------------------------------------------------------------------------------
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Function not smooth around x_center; excluding 0% offset.
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 9.6864e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Did not converge; using fallback.
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 8.6910e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 9.5386e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.1952e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.1061e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 4.0744e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.0407e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 2.4005e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 2.8286e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 4.2881e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.0252e-03
#   warnings.warn(message)
# /var/folders/0x/z32gfbyx2ls71tblrjjbdh0w0000gn/T/ipykernel_5725/570619246.py:9: RuntimeWarning: invalid value encountered in log
#   {"name": "ln(x + 2)", "func": lambda x: np.log(x + 2)},
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.6007e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.8199e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.0296e-03
#   warnings.warn(message)
# /var/folders/0x/z32gfbyx2ls71tblrjjbdh0w0000gn/T/ipykernel_5725/570619246.py:10: RuntimeWarning: invalid value encountered in sqrt
#   {"name": "sqrt(x + 1)", "func": lambda x: np.sqrt(x + 1)},
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.0913e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.1534e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 6.5718e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 8.3731e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 7.7231e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 8.1100e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 3.4050e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 9.3049e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 7.9058e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 3.0811e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 3.3707e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 7.1412e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 5.3582e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 7.6372e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 8.4287e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 7.0973e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 4.7742e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 4.3229e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 8.0743e-16
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 7.8949e-16
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 3.7956e-16
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 0.0000e+00
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 2.2204e-16
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 8.5811e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 4.4719e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 3.0616e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 5.8911e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.5433e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 8.4433e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.7882e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.9055e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 3.1479e-05
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 2.0556e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 9.8529e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 6.4617e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 3.3307e-16
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.1102e-16
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.2206e-05
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 9.4660e-05
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.3995e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.5735e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 2.5306e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 4.3560e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 2.9816e-13
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 3.7258e-05
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 6.5371e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 2.6740e-04
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 8.2414e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 5.8126e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 2.1698e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.5306e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 2.9664e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 4.3202e-05
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.4271e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 1.3541e-03
#   warnings.warn(message)
# /Users/niko/Documents/Research/Derivative-Calculator/hybrid_derivative_calculator.py:37: UserWarning: [stem_method] Converged with spread 3.2888e-04
#   warnings.warn(message)

# %%
def plot_function_with_residuals(f, x0, stem_slope, stencil_slope, dx=0.5,
                                 title="Function and Tangents + Residuals",
                                 save_path=None):
    x = np.linspace(x0 - dx, x0 + dx, 400)
    y = f(x)
    f0 = f(x0)

    # Tangents
    tangent_stem = stem_slope * (x - x0) + f0
    tangent_stencil = stencil_slope * (x - x0) + f0

    # Residuals
    residual_stem = y - tangent_stem
    residual_stencil = y - tangent_stencil

    # Set up two vertically stacked subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 7), sharex=True,
                                   gridspec_kw={'height_ratios': [2, 1]})

    # Top panel: function and tangents
    ax1.plot(x, y, label='Function', color='black')
    ax1.plot(x, tangent_stem, lw=2.5, label='Stem Tangent', color='yellowgreen')  # fixed here
    ax1.plot(x, tangent_stencil, '--', lw=2.5, label='Stencil Tangent', color='hotpink')
    ax1.axvline(x0, ls='--', lw=1.5, color='gray', alpha=0.6)
    ax1.set_ylabel("$f(x)$", fontsize=14)
    ax1.legend()
    ax1.set_title(title, fontsize=16)

    # Bottom panel: residuals
    ax2.plot(x, residual_stem, label='Stem Residual', color='yellowgreen', lw=2)
    ax2.plot(x, residual_stencil, label='Stencil Residual', color='hotpink', lw=2, ls="--")
    ax2.axhline(0, ls='--', color='gray', lw=1)
    ax2.set_xlabel("$x$", fontsize=14)
    ax2.set_ylabel("Residual", fontsize=13)
    ax2.legend()

    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.close(fig)

# %%
test_functions = {
    "x_squared": lambda x: x**2,
    "x_cubed": lambda x: x**3,
    "sin_x": lambda x: np.sin(x),
    "cos_x": lambda x: np.cos(x),
    "tan_x": lambda x: np.tan(x),
    "exp_x": lambda x: np.exp(x),
    "log_x_plus_2": lambda x: np.log(x + 2),
    "sqrt_x_plus_1": lambda x: np.sqrt(x + 1),
    "inv_1_plus_x2": lambda x: 1 / (1 + x**2),
    "x_sin_x": lambda x: x * np.sin(x),
    "x2_cos_x": lambda x: x**2 * np.cos(x),
    "x_exp_neg_x2": lambda x: x * np.exp(-x**2),
    "exp_sin5x": lambda x: np.exp(-x**2) * np.sin(5 * x),
    "log1px2_sinx": lambda x: np.log(1 + x**2) * np.sin(x),
    "sinx_cosx": lambda x: np.sin(x) * np.cos(x),
    "abs_x": lambda x: np.abs(x),
    "piecewise_quad_sqrt": lambda x: np.where(x < 0, x**2, np.sqrt(x + 1)),
    "piecewise_sin_cos": lambda x: np.where(x < 1, np.sin(x), np.cos(x)),
    "relu": lambda x: np.maximum(0, x),
    "x_times_absx": lambda x: x * abs(x),
    "heaviside": lambda x: np.where(x < 0, 0, 1),
    "sin_x2": lambda x: np.sin(x**2),
    "exp_sin_x": lambda x: np.exp(np.sin(x)),
    "log_cos2_plus_1": lambda x: np.log(np.cos(x)**2 + 1),
    "weird_combo": lambda x: x**3 * np.cos(x**2) + np.exp(-x**2),
}

# %%
def plot_all_derivatives(func_dict, x_center_list, save_dir="plots_tests"):
    os.makedirs(save_dir, exist_ok=True)

    for name, f in func_dict.items():
        for x0 in x_center_list:
            try:
                hdc = HybridDerivativeCalculator(f, x0, log_suffix=name)
                stem = hdc.stem_method()
                stencil = hdc.five_point_stencil_method()

                # Combined plot with function, tangents, and residuals
                plot_function_with_residuals(
                    f, x0, stem, stencil, dx=0.4,
                    title=f"{name} @ x={x0}",
                    save_path=os.path.join(save_dir, f"{name}_x{x0:.2f}_combined.png")
                )

            except Exception as e:
                print(f"❌ Error for {name} at x={x0}: {e}")

# %%
# %%time
x_vals = [-3.6, -0.5, 0.0, 0.5, 3.6]
plot_all_derivatives(test_functions, x_vals)
# Out:
# /var/folders/0x/z32gfbyx2ls71tblrjjbdh0w0000gn/T/ipykernel_5725/1814742081.py:8: RuntimeWarning: invalid value encountered in log
#   "log_x_plus_2": lambda x: np.log(x + 2),
# /var/folders/0x/z32gfbyx2ls71tblrjjbdh0w0000gn/T/ipykernel_5725/1814742081.py:9: RuntimeWarning: invalid value encountered in sqrt
#   "sqrt_x_plus_1": lambda x: np.sqrt(x + 1),
# /var/folders/0x/z32gfbyx2ls71tblrjjbdh0w0000gn/T/ipykernel_5725/1814742081.py:18: RuntimeWarning: invalid value encountered in sqrt
#   "piecewise_quad_sqrt": lambda x: np.where(x < 0, x**2, np.sqrt(x + 1)),
# CPU times: user 2min, sys: 6.47 s, total: 2min 6s
# Wall time: 2min 11s
